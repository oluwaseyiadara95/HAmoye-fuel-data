# %%
# Question 1

# %%
A = [1,2,3,4,5,6]
B = [13,21,34]

# %%
A.extend(B)

# %%
A
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
# Question 2

# %%
u = np.identity(3)

# %%
u
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
k = np.eye(3)

# %%
k
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
# Question 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data = pd.read_csv(url, error_bad_lines = False)

# %%
fuel_data.sample(6)
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 6347     f1_fuel_1999_12_32_2_9                32         1999
# 17695    f1_fuel_2008_12_51_1_4                51         2008
# 6986     f1_fuel_2000_12_44_2_2                44         2000
# 173      f1_fuel_1994_12_44_0_2                44         1994
# 1701    f1_fuel_1995_12_108_0_7               108         1995
# 9530   f1_fuel_2002_12_195_4_13               195         2002
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 6347               lombard                 gas       mcf         198561.0
# 17695    sl combined cycle                 gas       mcf        9071790.0
# 6986             northeast                 gas       mcf         210370.0
# 173    belle river (total)                coal       ton        4996518.0
# 1701      reid gardner 123                coal       ton         968902.0
# 9530           edgewater 4                coal       ton         302230.0
#
# ...

# %%
#Question 3

# %%
fuel_data.groupby(['fuel_type_code_pudl'])['fuel_cost_per_unit_burned'].mean().sort_values()
# Out:
# fuel_type_code_pudl
# gas          13.659397
# other        18.253856
# waste        19.518122
# coal         67.421830
# oil         168.877086
# nuclear    4955.157002
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
#Question 4

# %%
round(fuel_data['fuel_mmbtu_per_unit'].describe(),2)
# Out:
# count    29523.00
# mean         8.49
# std         10.60
# min          0.00
# 25%          1.02
# 50%          5.76
# 75%         17.01
# max        341.26
# Name: fuel_mmbtu_per_unit, dtype: float64

# %%
# Question 5

# %%
round(fuel_data['fuel_qty_burned'].skew(),2)
# Out:
# 15.85

# %%
round(fuel_data['fuel_qty_burned'].kurtosis(),2)
# Out:
# 651.37

# %%
# Question 6

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
k = fuel_data.isnull().sum()

total = k.max()
percent = (total/fuel_data.shape[0]) * 100

# %%
# return column with max missing values
total
# Out:
# 180

# %%
# rounding the percent of missing values in overall
round(percent,3)
# Out:
# 0.61

# %%
# Question 8

# %%
corr_matrix = fuel_data.corr()
corr_matrix
#fuel_data.corr(fuel_data['fuel_cost_per_unit_burned'])
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
corr_matrix['fuel_cost_per_unit_burned'].sort_values(ascending=True)
# Out:
# utility_id_ferc1               -0.037863
# fuel_qty_burned                -0.018535
# fuel_mmbtu_per_unit            -0.010034
# fuel_cost_per_mmbtu            -0.000437
# fuel_cost_per_unit_delivered    0.011007
# report_year                     0.013599
# fuel_cost_per_unit_burned       1.000000
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
# Questinm 9

# %%
fuel_data[fuel_data['fuel_type_code_pudl'] == 'coal']
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# 15        f1_fuel_1994_12_6_0_4                 6         1994
# 16        f1_fuel_1994_12_6_0_7                 6         1994
# 17       f1_fuel_1994_12_6_0_10                 6         1994
# 18       f1_fuel_1994_12_6_0_13                 6         1994
# ...

# %%
# QUestion 10

# %%
fuel_data.groupby('report_year')['fuel_cost_per_unit_delivered'].mean().sort_values(ascending=False)
# Out:
# report_year
# 1997    11140.197239
# 1996     9196.705948
# 2000      985.362877
# 2009      652.694163
# 2018      499.269966
# 2015      326.535511
# 1998      287.154420
# 2014      192.737183
# 2013      172.307591
# 2004      139.524275
# 2016      103.901761
# 2010       91.862105
# 1994       63.636060
# 2012       60.994502
# 2001       60.050396
# 2011       59.774667
# 2008       58.588197
# 2003       55.663493
# 2002       47.594361
# 2017       46.196861
# 2007       43.325023
# 2005       41.438184
# 2006       38.657484
# 1995       32.735269
# 1999       25.551627
# Name: fuel_cost_per_unit_delivered, dtype: float64
